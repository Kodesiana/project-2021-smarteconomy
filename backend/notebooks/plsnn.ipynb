# %%
import json

import numpy as np
import pandas as pd

import shap
from SALib.analyze import rbd_fast
from SALib.sample.morris import sample

from sklearn.model_selection import KFold
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler

from sqlalchemy import create_engine

# %%
cs = "mssql+pyodbc://smart-economy:ddsK^yiNTQ#^*2Gj@smart-economy-db.database.windows.net:1433/smart-economy?driver=ODBC+Driver+17+for+SQL+Server"
connection = create_engine(cs, connect_args={"check_same_thread": True})

df = pd.read_sql_query("SELECT [form] FROM [kuisioner]", connection)
df = pd.DataFrame([json.loads(row[1]) for row in df.itertuples()])

# %%
# df = pd.read_json("smarteconomy_dbo_kuisioner.json", orient="records")["form"].values
# df = pd.DataFrame([json.loads(row) for row in df])

# %%
df
# Out:
#     doc_id          x0_nama x0_jenis_kelamin      x0_no_hp  \
# 0                     OJANG                L  085723556067
# 1                      IWAN                L  084758574854
# 2                      DIAH                P  085647382635
# 3                      YULI                P  085647382635
# 4                     RATIH                P  085647382635
# ..     ...              ...              ...           ...
# 364    376              UEN                P  085721895756
# 365    377  IMAM JULIANSYAH                L  081221858565
# 366    378    SITI MARLINA                 P  085860952788
# 367    379             HERI                L  085611123434
# 368    380            EMAD                 L  085720939451
#
#     x0_status_di_kelompok  x0_domisili x0_kelas_bangunan_usaha x1_4 x1_19  \
# 0                       1    MEKARJAYA                  PETANI    5     2
# 1                       1     CIANAGA                   PETANI    1     1
# 2                       1  CIHAMERANG                   PETANI    1     2
# 3                       1   MEKARJAYA                 PEDAGANG    5     1
# 4                       1    MEKARJAYA                  PETANI    1     1
# ..                    ...          ...                     ...  ...   ...
# 364                     1    MEKARJAYA                  PETANI    1     3
# 365                     1    MEKARJAYA                    TANI    1     3
# 366                     1    MEKARJAYA               PEDAGANG     5     3
# 367                     1    MEKARJAYA                  PETANI    1     3
# 368                     1    MEKARJAYA                   TANI     1     2
#
#     x1_29_1  ... y2_114_a y2_114_b y2_115_a y2_115_b y2_116_a y2_116_b  \
# 0         0  ...        2        3        2        2        2        3
# 1         0  ...        3        4        2        4        2        4
# 2     50000  ...        3        4        3        4        3        4
# 3         0  ...        3        4        3        5        3        4
# 4         0  ...        3        3        3        3        3        3
# ..      ...  ...      ...      ...      ...      ...      ...      ...
# 364   50000  ...        4        3        4        3        4        3
# 365   50000  ...        2        3        2        3        2        3
# 366   50000  ...        4        5        3        4        2        3
# 367   50000  ...        2        3        2        3        1        3
# 368   70000  ...        2        4        3        4        3        4
#
#     y2_117_a y2_117_b y2_118_a y2_118_b
# 0          2        3        2        3
# 1          3        4        2        4
# 2          3        4        3        4
# 3          3        4        3        4
# 4          3        3        3        3
# ..       ...      ...      ...      ...
# 364        4        3        4        3
# 365        2        3        1        3
# 366        2        3        4        5
# 367        1        3        2        3
# 368        3        4        3        4
#
# [369 rows x 265 columns]

# %%
def summarize_variables(data: pd.DataFrame, var_name: str):
    IGNORED_COLS = [
        "x1_29_1",
        "x1_29_2",
        "x1_29_3",
        "x1_29_4",
        "x1_30_1",
        "x1_30_2",
        "x1_30_3",
        "x1_30_4",
    ]

    # pick the column with the var_name prefix and not in ignored columns
    indexes = [
        i
        for i, col in enumerate(df.columns)
        if col.startswith(var_name)
        and not col.endswith("_alasan")
        and not col.endswith("_tahun")
        and not col.endswith("_info")
        and not col.endswith("_frekuensi")
        and not col.endswith("_lainnya")
        and col not in IGNORED_COLS
    ]

    # get all row with column indexes
    summarize_df = df.iloc[:, indexes].astype(float).fillna(0)

    # get the mean of each row
    return summarize_df.mean(axis=1)

# %%
def analyze_sensitivity(model, features, bounds):
    # create problem space
    problem = {
        "num_vars": len(features),
        "names": features,
        "bounds": bounds,
    }

    # create samples
    param_values = sample(problem, 1000, num_levels=4, optimal_trajectories=None, seed=42)
    
    # run prediction
    preds = model.predict(param_values)

    # run sensitivity analysis
    sens = rbd_fast.analyze(problem, param_values, preds, conf_level=0.95, seed=42)

    return pd.DataFrame(sens, index=sens["names"])

# %%
df_summarize = pd.DataFrame({
    "X1": summarize_variables(df, "x1"),
    "X2": summarize_variables(df, "x2"),
    "X3": summarize_variables(df, "x3"),
    "X4": summarize_variables(df, "x4"),
    "X5": summarize_variables(df, "x5"),
    "Y1": summarize_variables(df, "y1"),
    "Y2": summarize_variables(df, "y2"),
})

df_summarize.head()
# Out:
#        X1        X2        X3    X4        X5        Y1        Y2
# 0  1.7500  3.000000  2.047619  2.75  2.403846  2.777778  2.304348
# 1  1.0625  2.000000  2.023810  2.40  2.615385  2.666667  2.728261
# 2  1.2500  2.000000  2.095238  2.45  2.826923  3.000000  2.739130
# 3  1.4375  2.333333  1.547619  2.35  3.000000  2.666667  2.858696
# 4  1.2500  2.166667  1.595238  3.00  2.826923  2.666667  2.728261

# %%
X = df_summarize[["X1", "X2", "X3", "X4", "X5", "Y1"]].values
y = pd.cut(df_summarize["Y2"].values, 3, labels=[1, 2, 3])

# %%
fold_nums = []
sensitivities = []

kfold = KFold(n_splits=10, shuffle=True, random_state=42)
for i, (train, test) in enumerate(kfold.split(X, y)):
    print("Running analysis for fold {}".format(i))
    
    # get the data
    X_train = X[train]
    y_train = y[train]

    # build the model
    model = MLPClassifier(max_iter=200, activation="relu", hidden_layer_sizes=(20), alpha=0.001, solver="adam", random_state=42)

    # fit model
    model.fit(X_train, y_train)

    # create problem space
    features = ["X1", "X2", "X3", "X4", "X5", "Y1"]
    bounds = [
        [X_train[:, 0].min(), X_train[:, 0].max()],
        [X_train[:, 1].min(), X_train[:, 1].max()],
        [X_train[:, 2].min(), X_train[:, 2].max()],
        [X_train[:, 3].min(), X_train[:, 3].max()],
        [X_train[:, 4].min(), X_train[:, 4].max()],
        [X_train[:, 5].min(), X_train[:, 5].max()],
    ]

    # run sensitivity analysis
    sensi = analyze_sensitivity(model, features, bounds)["S1"].values

    # save run data
    fold_nums.append(i)
    sensitivities.append(sensi)
# Out:
# Running analysis for fold 0
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 1
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 2
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 3
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 4
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 5
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 6
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 7
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 8
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# Running analysis for fold 9
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.

# %%
scaler = MinMaxScaler()

sensi_ori = np.nan_to_num(np.array(sensitivities))
sensi_scaled = scaler.fit_transform(sensi_ori)
sensi_means = np.mean(sensi_scaled, axis=0)
sensi_means
# Out:
# array([0.40580542, 0.44120659, 0.32161526, 0.48572695, 0.57395125,
#        0.34470136])

# %%
df_summ = pd.DataFrame(sensi_scaled, columns=["X1", "X2", "X3", "X4", "X5", "Y1"])
df_summ.loc["mean"] = df_summ.mean()
df_summ.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_be34e_row0_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_be34e_row0_col1, #T_be34e_row5_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_be34e_row0_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_be34e_row0_col3 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_be34e_row0_col4, #T_be34e_row10_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_be34e_row0_col5 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_be34e_row1_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_be34e_row1_col1 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_be34e_row1_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_be34e_row1_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_be34e_row1_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_be34e_row1_col5 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_be34e_row2_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_be34e_row2_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_be34e_row2_col2 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_be34e_row2_col3, #T_be34e_row3_col2, #T_be34e_row4_col4, #T_be34e_row4_col5, #T_be34e_row7_col5, #T_be34e_row8_col1, #T_be34e_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_be34e_row2_col4 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_be34e_row2_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_be34e_row3_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_be34e_row3_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_be34e_row3_col3, #T_be34e_row4_col1, #T_be34e_row6_col0, #T_be34e_row6_col2, #T_be34e_row6_col4, #T_be34e_row6_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_be34e_row3_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_be34e_row3_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_be34e_row4_col0, #T_be34e_row8_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_be34e_row4_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_be34e_row4_col3 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_be34e_row5_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_be34e_row5_col1, #T_be34e_row6_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_be34e_row5_col3 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_be34e_row5_col4 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_be34e_row5_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_be34e_row6_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_be34e_row7_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_be34e_row7_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_be34e_row7_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_be34e_row7_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_be34e_row7_col4 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_be34e_row8_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_be34e_row8_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_be34e_row8_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_be34e_row8_col5 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_be34e_row9_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_be34e_row9_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_be34e_row9_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_be34e_row9_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_be34e_row9_col5 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_be34e_row10_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_be34e_row10_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_be34e_row10_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_be34e_row10_col4 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_be34e_row10_col5 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# </style>
# <table id="T_be34e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be34e_level0_col0" class="col_heading level0 col0" >X1</th>
#       <th id="T_be34e_level0_col1" class="col_heading level0 col1" >X2</th>
#       <th id="T_be34e_level0_col2" class="col_heading level0 col2" >X3</th>
#       <th id="T_be34e_level0_col3" class="col_heading level0 col3" >X4</th>
#       <th id="T_be34e_level0_col4" class="col_heading level0 col4" >X5</th>
#       <th id="T_be34e_level0_col5" class="col_heading level0 col5" >Y1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be34e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be34e_row0_col0" class="data row0 col0" >0.611613</td>
#       <td id="T_be34e_row0_col1" class="data row0 col1" >0.382663</td>
#       <td id="T_be34e_row0_col2" class="data row0 col2" >0.117733</td>
#       <td id="T_be34e_row0_col3" class="data row0 col3" >0.902365</td>
#       <td id="T_be34e_row0_col4" class="data row0 col4" >0.486707</td>
#       <td id="T_be34e_row0_col5" class="data row0 col5" >0.163315</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be34e_row1_col0" class="data row1 col0" >0.134442</td>
#       <td id="T_be34e_row1_col1" class="data row1 col1" >0.887634</td>
#       <td id="T_be34e_row1_col2" class="data row1 col2" >0.143084</td>
#       <td id="T_be34e_row1_col3" class="data row1 col3" >0.327466</td>
#       <td id="T_be34e_row1_col4" class="data row1 col4" >0.595782</td>
#       <td id="T_be34e_row1_col5" class="data row1 col5" >0.167626</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be34e_row2_col0" class="data row2 col0" >0.798211</td>
#       <td id="T_be34e_row2_col1" class="data row2 col1" >0.198014</td>
#       <td id="T_be34e_row2_col2" class="data row2 col2" >0.145436</td>
#       <td id="T_be34e_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_be34e_row2_col4" class="data row2 col4" >0.577676</td>
#       <td id="T_be34e_row2_col5" class="data row2 col5" >0.115993</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be34e_row3_col0" class="data row3 col0" >0.237876</td>
#       <td id="T_be34e_row3_col1" class="data row3 col1" >0.421198</td>
#       <td id="T_be34e_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_be34e_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_be34e_row3_col4" class="data row3 col4" >0.857583</td>
#       <td id="T_be34e_row3_col5" class="data row3 col5" >0.298063</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be34e_row4_col0" class="data row4 col0" >0.425935</td>
#       <td id="T_be34e_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_be34e_row4_col2" class="data row4 col2" >0.362843</td>
#       <td id="T_be34e_row4_col3" class="data row4 col3" >0.070188</td>
#       <td id="T_be34e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_be34e_row4_col5" class="data row4 col5" >0.998549</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be34e_row5_col0" class="data row5 col0" >0.216272</td>
#       <td id="T_be34e_row5_col1" class="data row5 col1" >0.508631</td>
#       <td id="T_be34e_row5_col2" class="data row5 col2" >0.379559</td>
#       <td id="T_be34e_row5_col3" class="data row5 col3" >0.613645</td>
#       <td id="T_be34e_row5_col4" class="data row5 col4" >0.630343</td>
#       <td id="T_be34e_row5_col5" class="data row5 col5" >0.222392</td>
#     </tr>
#     <tr>
#       <th id="T_be34e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be34e_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_be34e_row6_col1" class="data row6 col1" >0.508814</td>
#       <td id="T_be34e_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_be34e_row6_col3" class="data row6 col3" >0.659471</td>
#       <td id="T_be34e_row6_col4"
